# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#READNING DATA
data=pd.read_csv("elcentro.csv")

# %%
#UNDERSTANDIN DATA
data.head()
# Out:
#    Time  Acceleration
# 0  0.00       0.00630
# 1  0.02       0.00364
# 2  0.04       0.00099
# 3  0.06       0.00428
# 4  0.08       0.00758

# %%
data.tail()
# Out:
#        Time  Acceleration
# 1555  31.10      -0.00019
# 1556  31.12      -0.00013
# 1557  31.14      -0.00006
# 1558  31.16       0.00000
# 1559  31.18       0.00000

# %%
data.shape
# Out:
# (1560, 2)

# %%
data.describe()
# Out:
#              Time  Acceleration
# count  1560.00000   1560.000000
# mean     15.59000      0.000002
# std       9.00955      0.061234
# min       0.00000     -0.318820
# 25%       7.79500     -0.028145
# 50%      15.59000     -0.001150
# 75%      23.38500      0.028580
# max      31.18000      0.298390

# %%
data.columns
# Out:
# Index(['Time', 'Acceleration'], dtype='object')

# %%
data.nunique()  #give total unique values
# Out:
# Time            1560
# Acceleration    1483
# dtype: int64

# %%
#Cleanin the data

# %%
data.isnull().sum()
# Out:
# Time            0
# Acceleration    0
# dtype: int64

# %%
# data1=data.drop(['Acceleration'],['Time'],axix=1)
#to drop an entire column

# %%
#RELATIONSHIP ANALYSIS

# %%
#co-realtion matrix
corelation=data.corr()

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data)

# %%
 sns.relplot(x='Time',y='Acceleration',data=data) 
 #can add "hue=male" kind of thing too into it

# %%
sns.distplot(data['Acceleration'],bins=50)
# Out:
# C:\Users\hrith\AppData\Local\Temp\ipykernel_21512\580584384.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Acceleration'],bins=50)
# <AxesSubplot:xlabel='Acceleration', ylabel='Density'>

# %%
sns.catplot(x='Acceleration',kind='box',data=data)
