# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
 #drawing a line
 plt.plot([1,2,3],[4,6,1])
 plt.show()

# %%
plt.plot([1,2,3],[2,5,7])

plt.title("Hrithik's data")    
plt.ylabel("This is y")
plt.xlabel("This is x")
plt.show()

# %%
 #drawing 2 lines
from matplotlib import style
style.use('ggplot') #addign style
x=[1,5,4]
y=[12,16,6]
x1=[5,9,11]
y2=[5,15,7]
plt.plot(x,y ,'g',label="first",linewidth=4) #'g'=green colour
plt.plot(x1,y2, label="second")

plt.legend() #the first and second thing in the chart
plt.grid(True,color='g')
plt.show()

# %%
#bar graph

# %%
plt.bar([1,3,5,7,9],[5,6,7,8,2],label="Example One")  
plt.bar([2,4,6,8,10],[8,6,2,5,6],label="Example One")
plt.legend()
plt.xlabel('bar number')
plt.ylabel('bar height')
plt.title('Info')
plt.show()

# %%
 #histogram
population_ages=[1,22,32,35,36,39,45,48,49,52,56,58,57,60,70,80,90,100,60,50,40]
bins=[0,10,20,33,40,50,60,70,80,90,100,110,120,130 ]
plt.hist(population_ages,bins,histtype='bar',rwidth=0.8)
plt.xlabel('x_bins')
plt.ylabel('y_no_of_ppl')
plt.title('Histogram')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np

x = np.random.normal(170, 10, 250)
#170: mean
#10:standard deviationo

print(x)
# Out:
# [153.14974562 194.75789098 163.2978322  184.50803754 180.74484663
#  178.99393797 173.36177464 174.70356921 154.57829109 173.18941724
#  163.27637638 163.49641824 161.94740066 170.49699976 164.04280919
#  177.65270084 183.40312031 175.68263535 175.5922101  163.03458059
#  171.5153564  191.33653036 181.08883398 159.18624411 161.44228276
#  174.40948721 160.3309971  166.34072026 191.97392646 174.04799412
#  156.27991482 165.92689343 178.82097849 178.74944993 166.27353636
#  178.20685841 163.60583684 175.50653554 171.44735872 188.23123272
#  168.36426172 168.31847848 175.23054294 169.94569782 178.86674989
#  170.56018937 155.58365756 164.56251339 172.06588417 164.22920829
#  170.51027437 166.19845576 181.46672028 169.95889065 172.46639956
#  168.517591   171.36175534 159.89803396 164.28255908 183.26122187
#  192.34168437 170.16238217 161.91499321 173.47455109 169.2748822
#  170.13414019 193.41783131 176.97259472 175.81659425 170.18601461
# ...

# %%
x = np.random.normal(170, 10, 250)
# randomly generate an array with 250 values, where the values will concentrate around 170, and the standard deviation is 10
plt.xlabel('Range')
plt.ylabel('y_no_values_in_that_range')
plt.title('Histogram')
plt.hist(x)
plt.show()

# %%
#scatter plot
x=[1,2,3,4,5,6,7,8]
y=[5,6,7,8,9,4,3,1]
t=x
plt.scatter(x,y,label="slitcat",color='g')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('scatter plot')
plt.legend()
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
x = np.linspace(-1, 1, 1000)
y = np.exp(x)
w = np.sin(x)
plt.scatter(x, y, c=w, marker='_')
#c:The marker colors
plt.colorbar()
plt.show()
# Out:
# C:\Users\hrith\AppData\Local\Temp\ipykernel_7196\3958827440.py:10: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %%
#stack plot
import matplotlib.pyplot as plt

days = [1,2,3,4,5]

sleep = [6,7,5,8,6]
eat =   [2,2,1,2,1]
work =  [5,7,10,8,6]
exercise=  [3,3,0,1,3]


plt.plot([],[],color='green', label='sleep', linewidth=3)
plt.plot([],[],color='blue', label='eat', linewidth=3)
plt.plot([],[],color='red', label='work', linewidth=3)
plt.plot([],[],color='black', label='play', linewidth=3)

plt.stackplot(days, sleep, eat, work, exercise, colors=['green','blue','red','black'])

plt.xlabel('days')
plt.ylabel('activities')
plt.title('5 DAY ROUTINE')
plt.legend()
plt.show()

# %%
days = [1,2,3,4,5]

sleep = [6,7,5,8,6]
eat =   [2,2,1,2,1]
work =  [5,7,10,8,6]
exercise=  [3,3,0,1,3]
plt.stackplot(days, sleep, eat, work, exercise, colors=['green','blue','red','black'])
plt.xlabel('days')
plt.ylabel('activities')
plt.title('5 DAY ROUTINE')

plt.show()

# %%
#pie chart

# %%
 import matplotlib.pyplot as plt
 
slices = [15,35,45,95]
activities = ['sleeping','eating','working','playing']
cols = ['c','m','r','b']
 
plt.pie(slices,
  labels=activities,
  colors=cols,
  startangle=90,
  shadow= True,
  explode=(0,0.1,0,0), #pulling ot a slice
  autopct='%1.1f%%')
 
plt.title('Pie Plot')
plt.show()

# %%
#working with multiple plots

# %%
#normal graph

import pandas as pd
from matplotlib import pyplot as plt

plt.style.use('seaborn')

data = pd.read_csv('data.csv')
ages = data['Age']
dev_salaries = data['All_Devs']
py_salaries = data['Python']
js_salaries = data['JavaScript']

plt.plot(ages, py_salaries, label='Python')
plt.plot(ages, js_salaries, label='JavaScript')

plt.plot(ages, dev_salaries, color='#444444',
         linestyle='--', label='All Devs')

plt.legend()

plt.title('Median Salary (USD) by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')

plt.tight_layout()

plt.show()

# %%
# drawing graph using axis
import pandas as pd
from matplotlib import pyplot as plt

plt.style.use('seaborn')

data = pd.read_csv('data.csv')
ages = data['Age']
dev_salaries = data['All_Devs']
py_salaries = data['Python']
js_salaries = data['JavaScript']

fig, ax = plt.subplots()


ax.plot(ages, dev_salaries, color='#444444',
         linestyle='--', label='All Devs')


ax.legend()
ax.set_title('Median Salary (USD) by Age')
ax.set_ylabel('Median Salary (USD)')



plt.tight_layout()

plt.show()

fig.savefig('fig1.png')

# %%
import pandas as pd
from matplotlib import pyplot as plt

plt.style.use('seaborn')

data = pd.read_csv('data.csv')
ages = data['Age']
dev_salaries = data['All_Devs']
py_salaries = data['Python']
js_salaries = data['JavaScript']

fig1, ax1 = plt.subplots()
fig2, ax2 = plt.subplots()

ax1.plot(ages, dev_salaries, color='#444444',
         linestyle='--', label='All Devs')

ax2.plot(ages, py_salaries, label='Python')
ax2.plot(ages, js_salaries, label='JavaScript')

ax1.legend()
ax1.set_title('Median Salary (USD) by Age')
ax1.set_ylabel('Median Salary (USD)')

ax2.legend()
ax2.set_xlabel('Ages')
ax2.set_ylabel('Median Salary (USD)')

plt.tight_layout()

plt.show()

fig1.savefig('fig1.png')
fig2.savefig('fig2.png')

# %%
#making grpahs

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x,a,b,c):
    return a*x*x + b*x + c

# %%
xlist=np.linspace(-10,10,num=1000)
ylist=f(xlist,3,1,4)
plt.plot(xlist,ylist,label="a")
plt.plot(xlist,ylist*2,label='b')

# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates
plt.style.use('seaborn')

# %%
#data
dates = [
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
] 
y = [0, 1, 3, 4, 6, 5, 7]

# %%
plt.plot_date(dates,y,linestyle='solid')

# %%
#changing the date format
date_format=mpl_dates.DateFormatter('%b, %d %y')
plt.gca().xaxis.set_major_formatter(date_format) #gca= get current axis
plt.plot_date(dates,y,linestyle='solid') #clling plot function

# %%
data = pd.read_csv('data1.csv') #read data from file 

#the dates were passed as strings in the start now we are converting it into datetime
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date', inplace=True) 

price_date = data['Date']
price_close = data['Close']

plt.plot_date(price_date, price_close, linestyle='solid')
plt.gcf().autofmt_xdate() #autoformatting dates

plt.title('Bitcoin Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.tight_layout() #just to look good

plt.show()

# %%
import random
from itertools import count
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')

# %%
x_vals = [0, 1, 2, 3, 4, 5]
y_vals = [0, 1, 3, 2, 3, 5]

plt.plot(x_vals, y_vals)

plt.tight_layout()
plt.show()

# %%
# learning subplots

x=[0,1,2,3,4]
y1=[50,20,30,10,40]
y2=[40,50,20,30,10]
y3=[20,70,10,40,30]

#plt.subplot(r,c,i)
#r=total rows, c=total columns ,i=index of individual plot(runs rightt to left and top to bottom)

plt.suptitle("multiple plots")

plt.subplot(2,2,1)
plt.plot(x,y1)
plt.title("plot1")

plt.subplot(2,2,2)
plt.plot(x,y2)
plt.title("plot2")

plt.subplot(2,2,3)
plt.plot(x,y3)
plt.title("plot 3")

plt.show()

# %%
#plotting axline:basically a infinite line
plt.axline((0, 0), (1, 1), linewidth=4, color='r')
#axline ((point1),(point2))

# %%
#axline using slope and a point as a paramater
plt.axline((0, 0), slope=0, linewidth=4, color='r')

# %%
#creating moving realtime graphs
import time
import psutil
import matplotlib.pyplot as plt

#to get graph in jupyter notebook itself
# %matplotlib notebook
plt.rcParams['animation.html'] = 'jshtml'


fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()
i = 0
x, y = [], []

while True:
    x.append(i)
    y.append(psutil.cpu_percent())
    
    ax.plot(x, y, color='b')
    
    fig.canvas.draw()
    
    ax.set_xlim(left=max(0, i-50), right=i+50)
    
    time.sleep(0.1)
    i += 1
plt.close()

# %%
#use this in VS code
import matplotlib.pyplot as plt
from matplotlib import animation
import pandas as pd

data=pd.read_csv('pokemon_data.csv')

count=0
x=[]
y=[]
def draw_graph(i):
    global count
    count +=1
    x.append(count)
    y.append(data['Attack'][count])
    plt.cla()
    plt.scatter(x,y)
    plt.plot(x,y)
    
anima=animation.FuncAnimation(plt.gcf(),draw_graph,interval=1500)
plt.show()
